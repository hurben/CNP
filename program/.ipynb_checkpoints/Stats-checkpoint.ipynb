# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy

rwr_summary_file = '//data/project/hurben/rwr.summary.table.txt'
df = pd.read_csv(rwr_summary_file, sep="\t", index_col=0)

tp_list = ['Ucp1','Cidea','Acsm3','Pdk4','Cpt1b','Acads','Acadm','Acadl','Acadvl','Hadha','Hadhb','Cox7a1','Cox8b']

# %%
# #print(df)
# print (df.index[1])
# print (df.loc['Ucp1'])
# ucp_list = list(df.loc['Ucp1'])
# print (ucp_list)

# #plt.hist(ucp_list)
# #plt.hist(df.loc['Ucp1'][0])
# #plt.show()

# p=sns.kdeplot(ucp_list)

# x,y = p.get_lines()[0].get_data()
# plt.vlines(df.loc['Ucp1'][0], 0, 100)
# plt.text(df.loc['Ucp1'][0],100, "Ucp1")
# Out:
# Ucp1
# origian    0.007835
# 1          0.000736
# 2          0.001877
# 3          0.004735
# 4          0.004735
# 5          0.002012
# 6          0.006930
# 7          0.000549
# 8          0.000442
# 9          0.002012
# 10         0.002392
# 11         0.004735
# 12         0.002012
# 13         0.002012
# 14         0.002012
# 15         0.002784
# 16         0.001412
# 17         0.003420
# 18         0.001320
# 19         0.001877
# 20         0.002599
# Name: Ucp1, dtype: float64
# [0.0078348226, 0.0007364703, 0.0018772751000000001, 0.0047346684, 0.0047346684, 0.0020122419, 0.006929632, 0.0005489531, 0.0004418512, 0.0020122419, 0.0023915988000000003, 0.0047346684, 0.0020122419, 0.0020122419, 0.0020122419, 0.0027841845, 0.0014115638, 0.0034198889, 0.0013202776000000001, 0.0018772751000000001, 0.0025988913]
# Text(0.0078348226, 100, 'Ucp1')

# %%
#print(df)

for tp_gene in tp_list:
    tp_value_list = list(df.loc[tp_gene])

    p = sns.kdeplot(tp_value_list)
    x,y = p.get_lines()[0].get_data()
    plt.vlines(df.loc[tp_gene][0], 0, 100)
    plt.text(df.loc[tp_gene][0],100, str(tp_gene))
    plt.show()
